# %% [markdown]
# #importar bibliotecas

# %%
import pandas as pd

# %% [markdown]
# #Tratar os arquivos

# %%
# Abrir o arquivo e substituir delimitadores
with open("dados/2022_corrigido.csv", "r") as file:
    content = file.read().replace(",", ";")  # Substituir ',' por ';'

# Salvar o conteúdo padronizado
with open("dados/2022_padronizado.csv", "w") as file:
    file.write(content)

# %% [markdown]
# #carregar os dados e eliminar colunas desnecessárias

# %%
# Carregar o CSV original
dados = pd.read_csv("dados/2022_padronizado.csv", delimiter=";", quotechar='"')

# Manter apenas as primeiras 30 colunas
dados = dados.iloc[:, :30]

# Salvar o arquivo atualizado
dados.to_csv("dados/2022_atualizados.csv", sep=";", index=False)

# Exibir informações para verificar
dados.head()
# Out:
#        id data_inversa    dia_semana   horario  uf   br    km  \
# 0  419121   2022-03-05        sábado  03:40:00  GO  153    67
# 1  424817   2022-04-05   terça-feira  17:20:00  PR  376   234
# 2  447524   2022-04-14  quinta-feira  19:15:00  GO  158    28
# 3  457724   2022-06-24   sexta-feira  12:00:00  MT  163  1046
# 4  464850   2022-07-30        sábado  06:00:00  MT  163   566
#
#              municipio                                     causa_acidente  \
# 0            PORANGATU               Demais falhas mecânicas ou elétricas
# 1         SERTANOPOLIS  Condutor deixou de manter distância do veículo...
# 2  BOM JARDIM DE GOIAS                     Ausência de reação do condutor
# 3   PEIXOTO DE AZEVEDO                                     Obras na pista
# 4           NOVA MUTUM           Reação tardia ou ineficiente do condutor
#
#                     tipo_acidente  ... feridos_graves ilesos ignorados  \
# 0                        Incêndio  ...              0      1         1
# 1                Colisão traseira  ...              1      1         0
# 2  Colisão lateral sentido oposto  ...              0      4         0
# 3  Colisão lateral sentido oposto  ...              1      1         3
# 4       Saída de leito carroçável  ...              0      0         2
#
#   feridos veiculos latitude longitude regional  delegacia             uop
# 0       0        2      -13       -49  SPRF-GO   DEL07-GO  UOP01-DEL07-GO
# 1       1        2      -23       -51  SPRF-PR   DEL07-PR  UOP02-DEL07-PR
# 2       0        2      -16       -52  SPRF-GO   DEL04-GO  UOP01-DEL04-GO
# 3       1        5      -10       -54  SPRF-MT   DEL06-MT    NPF/DEL06-MT
# 4       1        3      -14       -56  SPRF-MT   DEL01-MT  UOP01-DEL01-MT
#
# [5 rows x 30 columns]

# %% [markdown]
# #carregando dados organizados

# %%
dados_2021=pd.read_csv("dados/2021.csv", delimiter=';', encoding='latin1')
dados_2022=pd.read_csv("dados/2022_atualizados.csv", delimiter=';', encoding='latin1')
dados_2023=pd.read_csv("dados/2023.csv", delimiter=';', encoding='latin1')
dados_2024=pd.read_csv("dados/2024_atualizados.csv", delimiter=';', encoding='latin1')
# Out:
# /tmp/ipykernel_12847/1640930892.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados_2021=pd.read_csv("dados/2021.csv", delimiter=';', encoding='latin1')

# %% [markdown]
# #visualizar os dados

# %%
dados_2022.head()
# Out:
#        id data_inversa    dia_semana   horario  uf   br    km  \
# 0  419121   2022-03-05       sÃ¡bado  03:40:00  GO  153    67
# 1  424817   2022-04-05  terÃ§a-feira  17:20:00  PR  376   234
# 2  447524   2022-04-14  quinta-feira  19:15:00  GO  158    28
# 3  457724   2022-06-24   sexta-feira  12:00:00  MT  163  1046
# 4  464850   2022-07-30       sÃ¡bado  06:00:00  MT  163   566
#
#              municipio                                     causa_acidente  \
# 0            PORANGATU             Demais falhas mecÃ¢nicas ou elÃ©tricas
# 1         SERTANOPOLIS  Condutor deixou de manter distÃ¢ncia do veÃ­cu...
# 2  BOM JARDIM DE GOIAS                  AusÃªncia de reaÃ§Ã£o do condutor
# 3   PEIXOTO DE AZEVEDO                                     Obras na pista
# 4           NOVA MUTUM         ReaÃ§Ã£o tardia ou ineficiente do condutor
#
#                      tipo_acidente  ... feridos_graves ilesos ignorados  \
# 0                        IncÃªndio  ...              0      1         1
# 1                ColisÃ£o traseira  ...              1      1         0
# 2  ColisÃ£o lateral sentido oposto  ...              0      4         0
# 3  ColisÃ£o lateral sentido oposto  ...              1      1         3
# 4     SaÃ­da de leito carroÃ§Ã¡vel  ...              0      0         2
#
#   feridos veiculos latitude longitude regional  delegacia             uop
# 0       0        2      -13       -49  SPRF-GO   DEL07-GO  UOP01-DEL07-GO
# 1       1        2      -23       -51  SPRF-PR   DEL07-PR  UOP02-DEL07-PR
# 2       0        2      -16       -52  SPRF-GO   DEL04-GO  UOP01-DEL04-GO
# 3       1        5      -10       -54  SPRF-MT   DEL06-MT    NPF/DEL06-MT
# 4       1        3      -14       -56  SPRF-MT   DEL01-MT  UOP01-DEL01-MT
#
# [5 rows x 30 columns]

# %% [markdown]
# #Consolidar e Salvar os dados

# %%
# Concatene os DataFrames após tratamento
dados_consolidados = pd.concat([dados_2021, dados_2022, dados_2023, dados_2024], ignore_index=True)

# Salve o arquivo final
dados_consolidados.to_csv("dados/dados_consolidados.csv", index=False)
dados_consolidados
# Out:
#             id data_inversa     dia_semana   horario  uf   br     km  \
# 0       331730   01/01/2021    sexta-feira  05:30:00  SP  116    453
# 1       331804   01/01/2021    sexta-feira  08:05:00  AM  174    937
# 2       331815   01/01/2021    sexta-feira  10:10:00  CE  222  128,5
# 3       331823   01/01/2021    sexta-feira  12:30:00  RJ  493     18
# 4       331843   01/01/2021    sexta-feira  14:40:00  RJ  393    252
# ...        ...          ...            ...       ...  ..  ...    ...
# 132366  586131   2024-03-09        sÃ¡bado  15:40:00  BA  242    865
# 132367  610460   2024-04-20        sÃ¡bado  23:45:00  BA   20    180
# 132368  617635   2024-07-29  segunda-feira  08:15:00  PR  369     29
# 132369  620724   2024-08-11        domingo  14:00:00  AM  319    253
# 132370  629132   2024-09-19   quinta-feira  12:20:00  SP  116    288
#
#                   municipio  \
# 0                  REGISTRO
# 1                    MANAUS
# 2                   ITAPAJE
# 3                      MAGE
# 4            BARRA DO PIRAI
# ...                     ...
# 132366            BARREIRAS
# 132367            BARREIRAS
# 132368              CAMBARA
# 132369            MANAQUIRI
# 132370  SAO JOSE DOS CAMPOS
#
#                                            causa_acidente      tipo_acidente  \
# 0                Reação tardia ou ineficiente do condutor         Tombamento
# 1                Reação tardia ou ineficiente do condutor   Colisão traseira
# 2                                 Velocidade Incompatível         Tombamento
# 3       Ingestão de álcool e/ou substâncias psicoativa...    Colisão lateral
# 4                                       Condutor Dormindo    Colisão frontal
# ...                                                   ...                ...
# 132366         ReaÃ§Ã£o tardia ou ineficiente do condutor  ColisÃ£o traseira
# 132367         ReaÃ§Ã£o tardia ou ineficiente do condutor         Tombamento
# 132368             Demais falhas mecÃ¢nicas ou elÃ©tricas         Tombamento
# 132369     Acumulo de areia ou detritos sobre o pavimento  ColisÃ£o traseira
# 132370                  AusÃªncia de reaÃ§Ã£o do condutor   ColisÃ£o frontal
#
#         ... feridos_graves ilesos ignorados feridos veiculos      latitude  \
# 0       ...              0      0         0       1        1  -24,56168114
# 1       ...              0      5         1       1        5     -2,508068
# 2       ...              0      0        11       2       12     -3,707626
# 3       ...              0      1         1       1        3   -22,6687122
# 4       ...              1      1         1       2        3  -22,43422023
# ...     ...            ...    ...       ...     ...      ...           ...
# 132366  ...              0      5         0       0        2           -12
# 132367  ...              0      0         0       1        1           -12
# 132368  ...              0      1         0       0        1             1
# 132369  ...              0      0         6       0        0             2
# 132370  ...              1      0         4       0        1             3
#
#            longitude regional  delegacia             uop
# 0       -47,86752174  SPRF-SP   DEL05-SP  UOP01-DEL05-SP
# 1         -60,036434  SPRF-AM   DEL01-AM  UOP01-DEL01-AM
# 2         -39,623509  SPRF-CE   DEL04-CE  UOP03-DEL04-CE
# 3       -43,01862696  SPRF-RJ   DEL04-RJ  UOP02-DEL04-RJ
# 4       -43,77561487  SPRF-RJ   DEL05-RJ  UOP04-DEL05-RJ
# ...              ...      ...        ...             ...
# 132366           -45  SPRF-BA   DEL10-BA  UOP01-DEL10-BA
# 132367           -45  SPRF-BA   DEL10-BA  UOP01-DEL10-BA
# 132368           -23      -50    SPRF-PR        DEL07-PR
# 132369            -4      -61    SPRF-AM        DEL01-AM
# 132370           -23      -46    SPRF-SP        DEL04-SP
#
# [132371 rows x 30 columns]

# %%
dados_consolidados
# Out:
#             id data_inversa     dia_semana   horario  uf   br     km  \
# 0       331730   01/01/2021    sexta-feira  05:30:00  SP  116    453
# 1       331804   01/01/2021    sexta-feira  08:05:00  AM  174    937
# 2       331815   01/01/2021    sexta-feira  10:10:00  CE  222  128,5
# 3       331823   01/01/2021    sexta-feira  12:30:00  RJ  493     18
# 4       331843   01/01/2021    sexta-feira  14:40:00  RJ  393    252
# ...        ...          ...            ...       ...  ..  ...    ...
# 132366  586131   2024-03-09        sÃ¡bado  15:40:00  BA  242    865
# 132367  610460   2024-04-20        sÃ¡bado  23:45:00  BA   20    180
# 132368  617635   2024-07-29  segunda-feira  08:15:00  PR  369     29
# 132369  620724   2024-08-11        domingo  14:00:00  AM  319    253
# 132370  629132   2024-09-19   quinta-feira  12:20:00  SP  116    288
#
#                   municipio  \
# 0                  REGISTRO
# 1                    MANAUS
# 2                   ITAPAJE
# 3                      MAGE
# 4            BARRA DO PIRAI
# ...                     ...
# 132366            BARREIRAS
# 132367            BARREIRAS
# 132368              CAMBARA
# 132369            MANAQUIRI
# 132370  SAO JOSE DOS CAMPOS
#
#                                            causa_acidente      tipo_acidente  \
# 0                Reação tardia ou ineficiente do condutor         Tombamento
# 1                Reação tardia ou ineficiente do condutor   Colisão traseira
# 2                                 Velocidade Incompatível         Tombamento
# 3       Ingestão de álcool e/ou substâncias psicoativa...    Colisão lateral
# 4                                       Condutor Dormindo    Colisão frontal
# ...                                                   ...                ...
# 132366         ReaÃ§Ã£o tardia ou ineficiente do condutor  ColisÃ£o traseira
# 132367         ReaÃ§Ã£o tardia ou ineficiente do condutor         Tombamento
# 132368             Demais falhas mecÃ¢nicas ou elÃ©tricas         Tombamento
# 132369     Acumulo de areia ou detritos sobre o pavimento  ColisÃ£o traseira
# 132370                  AusÃªncia de reaÃ§Ã£o do condutor   ColisÃ£o frontal
#
#         ... feridos_graves ilesos ignorados feridos veiculos      latitude  \
# 0       ...              0      0         0       1        1  -24,56168114
# 1       ...              0      5         1       1        5     -2,508068
# 2       ...              0      0        11       2       12     -3,707626
# 3       ...              0      1         1       1        3   -22,6687122
# 4       ...              1      1         1       2        3  -22,43422023
# ...     ...            ...    ...       ...     ...      ...           ...
# 132366  ...              0      5         0       0        2           -12
# 132367  ...              0      0         0       1        1           -12
# 132368  ...              0      1         0       0        1             1
# 132369  ...              0      0         6       0        0             2
# 132370  ...              1      0         4       0        1             3
#
#            longitude regional  delegacia             uop
# 0       -47,86752174  SPRF-SP   DEL05-SP  UOP01-DEL05-SP
# 1         -60,036434  SPRF-AM   DEL01-AM  UOP01-DEL01-AM
# 2         -39,623509  SPRF-CE   DEL04-CE  UOP03-DEL04-CE
# 3       -43,01862696  SPRF-RJ   DEL04-RJ  UOP02-DEL04-RJ
# 4       -43,77561487  SPRF-RJ   DEL05-RJ  UOP04-DEL05-RJ
# ...              ...      ...        ...             ...
# 132366           -45  SPRF-BA   DEL10-BA  UOP01-DEL10-BA
# 132367           -45  SPRF-BA   DEL10-BA  UOP01-DEL10-BA
# 132368           -23      -50    SPRF-PR        DEL07-PR
# 132369            -4      -61    SPRF-AM        DEL01-AM
# 132370           -23      -46    SPRF-SP        DEL04-SP
#
# [132371 rows x 30 columns]
